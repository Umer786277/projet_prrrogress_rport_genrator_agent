# %% [markdown]
# **L1: Automated Project: Planning, Estimation, and Allocation¶**

# %%
# !pip install crewai
# Out:
# Collecting crewai
#   Downloading crewai-0.102.0-py3-none-any.whl.metadata (28 kB)
# Collecting appdirs>=1.4.4 (from crewai)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting auth0-python>=4.7.1 (from crewai)
#   Downloading auth0_python-4.8.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from crewai) (1.9.0)
# Collecting chromadb>=0.5.23 (from crewai)
#   Downloading chromadb-0.6.3-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: click>=8.1.7 in /usr/local/lib/python3.11/dist-packages (from crewai) (8.1.8)
# Collecting instructor>=1.3.3 (from crewai)
#   Downloading instructor-1.7.2-py3-none-any.whl.metadata (18 kB)
# Collecting json-repair>=0.25.2 (from crewai)
#   Downloading json_repair-0.39.0-py3-none-any.whl.metadata (11 kB)
# Collecting json5>=0.10.0 (from crewai)
#   Downloading json5-0.10.0-py3-none-any.whl.metadata (34 kB)
# Collecting jsonref>=1.1.0 (from crewai)
#   Downloading jsonref-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting litellm==1.60.2 (from crewai)
#   Downloading litellm-1.60.2-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: openai>=1.13.3 in /usr/local/lib/python3.11/dist-packages (from crewai) (1.61.1)
# Requirement already satisfied: openpyxl>=3.1.5 in /usr/local/lib/python3.11/dist-packages (from crewai) (3.1.5)
# Collecting opentelemetry-api>=1.22.0 (from crewai)
#   Downloading opentelemetry_api-1.30.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-exporter-otlp-proto-http>=1.22.0 (from crewai)
#   Downloading opentelemetry_exporter_otlp_proto_http-1.30.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-sdk>=1.22.0 (from crewai)
#   Downloading opentelemetry_sdk-1.30.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting pdfplumber>=0.11.4 (from crewai)
#   Downloading pdfplumber-0.11.5-py3-none-any.whl.metadata (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: pydantic>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from crewai) (2.10.6)
# Collecting python-dotenv>=1.0.0 (from crewai)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting pyvis>=0.3.2 (from crewai)
#   Downloading pyvis-0.3.2-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: regex>=2024.9.11 in /usr/local/lib/python3.11/dist-packages (from crewai) (2024.11.6)
# Collecting tomli-w>=1.1.0 (from crewai)
#   Downloading tomli_w-1.2.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting tomli>=2.0.2 (from crewai)
#   Downloading tomli-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting uv>=0.4.25 (from crewai)
#   Downloading uv-0.6.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from litellm==1.60.2->crewai) (3.11.12)
# Collecting httpx<0.28.0,>=0.23.0 (from litellm==1.60.2->crewai)
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /usr/local/lib/python3.11/dist-packages (from litellm==1.60.2->crewai) (8.6.1)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from litellm==1.60.2->crewai) (3.1.5)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from litellm==1.60.2->crewai) (4.23.0)
# Collecting tiktoken>=0.7.0 (from litellm==1.60.2->crewai)
#   Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.11/dist-packages (from litellm==1.60.2->crewai) (0.21.0)
# Requirement already satisfied: cryptography>=43.0.1 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai) (43.0.3)
# Requirement already satisfied: pyjwt>=2.8.0 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai) (2.10.1)
# Requirement already satisfied: requests>=2.32.3 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai) (2.32.3)
# Requirement already satisfied: urllib3>=2.2.3 in /usr/local/lib/python3.11/dist-packages (from auth0-python>=4.7.1->crewai) (2.3.0)
# Collecting build>=1.0.3 (from chromadb>=0.5.23->crewai)
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Collecting chroma-hnswlib==0.7.6 (from chromadb>=0.5.23->crewai)
#   Downloading chroma_hnswlib-0.7.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (252 bytes)
# Collecting fastapi>=0.95.2 (from chromadb>=0.5.23->crewai)
#   Downloading fastapi-0.115.8-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai)
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.22.5 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (1.26.4)
# Collecting posthog>=2.4.0 (from chromadb>=0.5.23->crewai)
#   Downloading posthog-3.14.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing_extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb>=0.5.23->crewai)
#   Downloading onnxruntime-1.20.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb>=0.5.23->crewai)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.30.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb>=0.5.23->crewai)
#   Downloading opentelemetry_instrumentation_fastapi-0.51b0-py3-none-any.whl.metadata (2.2 kB)
# Collecting pypika>=0.48.9 (from chromadb>=0.5.23->crewai)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 4.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (4.67.1)
# Collecting overrides>=7.3.1 (from chromadb>=0.5.23->crewai)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (1.70.0)
# Collecting bcrypt>=4.0.1 (from chromadb>=0.5.23->crewai)
#   Downloading bcrypt-4.2.1-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (9.8 kB)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (0.15.1)
# Collecting kubernetes>=28.1.0 (from chromadb>=0.5.23->crewai)
#   Downloading kubernetes-32.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb>=0.5.23->crewai)
#   Downloading mmh3-5.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (3.10.15)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from chromadb>=0.5.23->crewai) (13.9.4)
# Requirement already satisfied: docstring-parser<1.0,>=0.16 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai) (0.16)
# Requirement already satisfied: jiter<0.9,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai) (0.8.2)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from instructor>=1.3.3->crewai) (2.27.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.13.3->crewai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai>=1.13.3->crewai) (1.3.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl>=3.1.5->crewai) (2.0.0)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api>=1.22.0->crewai) (1.2.18)
# Collecting importlib-metadata>=6.8.0 (from litellm==1.60.2->crewai)
#   Downloading importlib_metadata-8.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.67.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.30.0 (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.30.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.30.0 (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai)
#   Downloading opentelemetry_proto-1.30.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting protobuf<6.0,>=5.0 (from opentelemetry-proto==1.30.0->opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai)
#   Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting opentelemetry-semantic-conventions==0.51b0 (from opentelemetry-sdk>=1.22.0->crewai)
#   Downloading opentelemetry_semantic_conventions-0.51b0-py3-none-any.whl.metadata (2.5 kB)
# Collecting pdfminer.six==20231228 (from pdfplumber>=0.11.4->crewai)
#   Downloading pdfminer.six-20231228-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.11/dist-packages (from pdfplumber>=0.11.4->crewai) (11.1.0)
# Collecting pypdfium2>=4.18.0 (from pdfplumber>=0.11.4->crewai)
#   Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six==20231228->pdfplumber>=0.11.4->crewai) (3.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=2.4.2->crewai) (0.7.0)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from pyvis>=0.3.2->crewai) (7.34.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from pyvis>=0.3.2->crewai) (4.0.1)
# Requirement already satisfied: networkx>=1.11 in /usr/local/lib/python3.11/dist-packages (from pyvis>=0.3.2->crewai) (3.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.60.2->crewai) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.60.2->crewai) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.60.2->crewai) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.60.2->crewai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.60.2->crewai) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.60.2->crewai) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->litellm==1.60.2->crewai) (1.18.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai>=1.13.3->crewai) (3.10)
# Requirement already satisfied: packaging>=19.1 in /usr/local/lib/python3.11/dist-packages (from build>=1.0.3->chromadb>=0.5.23->crewai) (24.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb>=0.5.23->crewai)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=43.0.1->auth0-python>=4.7.1->crewai) (1.17.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated>=1.2.6->opentelemetry-api>=1.22.0->crewai) (1.17.2)
# Collecting starlette<0.46.0,>=0.40.0 (from fastapi>=0.95.2->chromadb>=0.5.23->crewai)
#   Downloading starlette-0.45.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.23.0->litellm==1.60.2->crewai) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<0.28.0,>=0.23.0->litellm==1.60.2->crewai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.23.0->litellm==1.60.2->crewai) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata>=6.8.0->litellm==1.60.2->crewai) (3.21.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (75.1.0)
# Collecting jedi>=0.16 (from ipython>=5.3.0->pyvis>=0.3.2->crewai)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2<4.0.0,>=3.1.2->litellm==1.60.2->crewai) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.60.2->crewai) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.60.2->crewai) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.60.2->crewai) (0.22.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.11/dist-packages (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (3.2.2)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb>=0.5.23->crewai)
#   Downloading durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (25.2.10)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (1.13.1)
# Collecting opentelemetry-instrumentation-asgi==0.51b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai)
#   Downloading opentelemetry_instrumentation_asgi-0.51b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation==0.51b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai)
#   Downloading opentelemetry_instrumentation-0.51b0-py3-none-any.whl.metadata (6.3 kB)
# Collecting opentelemetry-util-http==0.51b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai)
#   Downloading opentelemetry_util_http-0.51b0-py3-none-any.whl.metadata (2.6 kB)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.51b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.5.23->crewai)
#   Downloading asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb>=0.5.23->crewai)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb>=0.5.23->crewai)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->chromadb>=0.5.23->crewai) (3.0.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers->litellm==1.60.2->crewai) (0.28.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->chromadb>=0.5.23->crewai) (1.5.4)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai)
#   Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.6 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai)
#   Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai)
#   Downloading watchfiles-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/dist-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.5.23->crewai) (14.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=43.0.1->auth0-python>=4.7.1->crewai) (2.22)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (5.5.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (4.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm==1.60.2->crewai) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers->litellm==1.60.2->crewai) (2024.10.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.5.23->crewai) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.13)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.5.23->crewai) (1.3.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.5.23->crewai) (0.6.1)
# Downloading crewai-0.102.0-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.2/240.2 kB 6.0 MB/s eta 0:00:00
# Downloading litellm-1.60.2-py3-none-any.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 65.3 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading auth0_python-4.8.0-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.0/134.0 kB 9.3 MB/s eta 0:00:00
# Downloading chromadb-0.6.3-py3-none-any.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.1/611.1 kB 33.8 MB/s eta 0:00:00
# Downloading chroma_hnswlib-0.7.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 65.7 MB/s eta 0:00:00
# Downloading instructor-1.7.2-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 kB 4.8 MB/s eta 0:00:00
# Downloading json_repair-0.39.0-py3-none-any.whl (20 kB)
# Downloading json5-0.10.0-py3-none-any.whl (34 kB)
# Downloading jsonref-1.1.0-py3-none-any.whl (9.4 kB)
# Downloading opentelemetry_api-1.30.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 4.3 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_http-1.30.0-py3-none-any.whl (17 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.30.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.30.0-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 3.1 MB/s eta 0:00:00
# Downloading opentelemetry_sdk-1.30.0-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 8.0 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions-0.51b0-py3-none-any.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.4/177.4 kB 11.3 MB/s eta 0:00:00
# Downloading pdfplumber-0.11.5-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 4.2 MB/s eta 0:00:00
# Downloading pdfminer.six-20231228-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 76.8 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading pyvis-0.3.2-py3-none-any.whl (756 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 37.0 MB/s eta 0:00:00
# Downloading tomli-2.2.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (236 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.0/236.0 kB 16.2 MB/s eta 0:00:00
# Downloading tomli_w-1.2.0-py3-none-any.whl (6.7 kB)
# Downloading uv-0.6.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 68.2 MB/s eta 0:00:00
# Downloading bcrypt-4.2.1-cp39-abi3-manylinux_2_28_x86_64.whl (278 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.6/278.6 kB 17.7 MB/s eta 0:00:00
# Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading fastapi-0.115.8-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 6.4 MB/s eta 0:00:00
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.2 MB/s eta 0:00:00
# Downloading importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# Downloading kubernetes-32.0.0-py2.py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 48.4 MB/s eta 0:00:00
# Downloading mmh3-5.1.0-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 6.4 MB/s eta 0:00:00
# Downloading onnxruntime-1.20.1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (13.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 73.2 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.30.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_instrumentation_fastapi-0.51b0-py3-none-any.whl (12 kB)
# Downloading opentelemetry_instrumentation-0.51b0-py3-none-any.whl (30 kB)
# Downloading opentelemetry_instrumentation_asgi-0.51b0-py3-none-any.whl (16 kB)
# Downloading opentelemetry_util_http-0.51b0-py3-none-any.whl (7.3 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-3.14.1-py2.py3-none-any.whl (73 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.3/73.3 kB 4.7 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 69.2 MB/s eta 0:00:00
# Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 47.3 MB/s eta 0:00:00
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.4 MB/s eta 0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading durationpy-0.9-py3-none-any.whl (3.5 kB)
# Downloading httptools-0.6.4-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (459 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 29.6 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 63.0 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 21.6 MB/s eta 0:00:00
# Downloading starlette-0.45.3-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 5.4 MB/s eta 0:00:00
# Downloading uvloop-0.21.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 80.7 MB/s eta 0:00:00
# Downloading watchfiles-1.0.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (452 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.6/452.6 kB 24.8 MB/s eta 0:00:00
# Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.0 MB/s eta 0:00:00
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.9 MB/s eta 0:00:00
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53771 sha256=660198c0517763dd46adf6170b521009971d40c24c16f49acfeb5efd83d2f78d
#   Stored in directory: /root/.cache/pip/wheels/a3/01/bd/4c40ceb9d5354160cb186dcc153360f4ab7eb23e2b24daf96d
# Successfully built pypika
# Installing collected packages: pypika, monotonic, durationpy, appdirs, uvloop, uvicorn, uv, tomli-w, tomli, python-dotenv, pyproject_hooks, pypdfium2, protobuf, overrides, opentelemetry-util-http, mmh3, jsonref, json5, json-repair, jedi, importlib-metadata, humanfriendly, httptools, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, tiktoken, starlette, posthog, opentelemetry-proto, opentelemetry-api, httpx, coloredlogs, build, pyvis, pdfminer.six, opentelemetry-semantic-conventions, opentelemetry-exporter-otlp-proto-common, onnxruntime, kubernetes, fastapi, auth0-python, pdfplumber, opentelemetry-sdk, opentelemetry-instrumentation, litellm, instructor, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb, crewai
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.6
#     Uninstalling protobuf-4.25.6:
#       Successfully uninstalled protobuf-4.25.6
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.6.1
#     Uninstalling importlib_metadata-8.6.1:
#       Successfully uninstalled importlib_metadata-8.6.1
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.16.0
#     Uninstalling opentelemetry-api-1.16.0:
#       Successfully uninstalled opentelemetry-api-1.16.0
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.1
#     Uninstalling httpx-0.28.1:
#       Successfully uninstalled httpx-0.28.1
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.37b0
#     Uninstalling opentelemetry-semantic-conventions-0.37b0:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.37b0
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.16.0
#     Uninstalling opentelemetry-sdk-1.16.0:
#       Successfully uninstalled opentelemetry-sdk-1.16.0
# Successfully installed appdirs-1.4.4 asgiref-3.8.1 auth0-python-4.8.0 backoff-2.2.1 bcrypt-4.2.1 build-1.2.2.post1 chroma-hnswlib-0.7.6 chromadb-0.6.3 coloredlogs-15.0.1 crewai-0.102.0 durationpy-0.9 fastapi-0.115.8 httptools-0.6.4 httpx-0.27.2 humanfriendly-10.0 importlib-metadata-8.5.0 instructor-1.7.2 jedi-0.19.2 json-repair-0.39.0 json5-0.10.0 jsonref-1.1.0 kubernetes-32.0.0 litellm-1.60.2 mmh3-5.1.0 monotonic-1.6 onnxruntime-1.20.1 opentelemetry-api-1.30.0 opentelemetry-exporter-otlp-proto-common-1.30.0 opentelemetry-exporter-otlp-proto-grpc-1.30.0 opentelemetry-exporter-otlp-proto-http-1.30.0 opentelemetry-instrumentation-0.51b0 opentelemetry-instrumentation-asgi-0.51b0 opentelemetry-instrumentation-fastapi-0.51b0 opentelemetry-proto-1.30.0 opentelemetry-sdk-1.30.0 opentelemetry-semantic-conventions-0.51b0 opentelemetry-util-http-0.51b0 overrides-7.7.0 pdfminer.six-20231228 pdfplumber-0.11.5 posthog-3.14.1 protobuf-5.29.3 pypdfium2-4.30.1 pypika-0.48.9 pyproject_hooks-1.2.0 python-dotenv-1.0.1 pyvis-0.3.2 starlette-0.45.3 tiktoken-0.9.0 tomli-2.2.1 tomli-w-1.2.0 uv-0.6.1 uvicorn-0.34.0 uvloop-0.21.0 watchfiles-1.0.4

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')


import os
import yaml
from crewai import Agent, Task, Crew

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'
os.environ["OPENAI_API_KEY"] = ""

# %%
# Define file paths for YAML configurations
files = {
    'agents': '/content/agents.yaml',
    'tasks': '/content/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent'],

)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)
# Out:
# WARNING:opentelemetry.trace:Overriding of current TracerProvider is not allowed

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# **Website Project Plan**
#
# **Project Overview:**
# Create a responsive and visually appealing website for a small business that effectively communicates its offerings and enhances customer engagement.
#
# ### Detailed Task Breakdown:
#
# | Task ID | Task Description                                                                            | Responsible | Scope Detail                                                                                                                                                 | Timeline     | Dependencies                | Deliverables                        |
# |---------|---------------------------------------------------------------------------------------------|-------------|-------------------------------------------------------------------------------------------------------------------------------------------------------------|--------------|-----------------------------|-------------------------------------|
# | 1       | Gather and finalize project requirements                                                    | John Doe    | Collaborate with stakeholders to understand business needs, design expectations, and technical constraints.                                               | Week 1       | None                        | Project requirement document        |
# | 2       | Create a site map and wireframe for the website                                            | Bob Smith   | Design the overall structure of the website, including navigation, layout, and key pages using wireframes.                                                | Week 2       | Task 1                     | Site map and wireframes             |
# | 3       | Design responsive website UI                                                                | Bob Smith   | Develop a modern, visually appealing design for both desktop and mobile interfaces ensuring usability and aesthetic appeal.                                 | Weeks 3-4    | Task 2                     | UI design prototypes                |
# | 4       | Develop website frontend initiative                                                         | Jane Doe    | Coding of the website's frontend using HTML, CSS, and JavaScript to align with the approved UI designs.                                                   | Weeks 5-7    | Task 3                     | Functional website frontend         |
# | 5       | Build user-friendly navigation system                                                       | Jane Doe    | Implement a clear and intuitive menu structure ensuring ease of access to all sections of the site.                                                       | Week 7       | Task 4                     | Navigation system implementation    |
# | 6       | Create "About Us" page                                                                      | Jane Doe    | Develop content that highlights the company's history, mission, and values including images and formatting.                                               | Week 8       | Task 4                     | Populated "About Us" page          |
# | 7       | Design "Services" page                                                                      | Jane Doe    | Showcase business offerings with detailed descriptions and engaging visuals for each service provided.                                                    | Week 8       | Task 4                     | Populated "Services" page          |
# | 8       | Create "Contact Us" page                                                                    | Jane Doe    | Integrate a contact form and an interactive map for customers to easily reach out to the business.                                                        | Week 9       | Task 4                     | Functional "Contact Us" page       |
# | 9       | Implement a blog section                                                                     | Jane Doe    | Set up a blog area for publishing updates, industry news, and company achievements for better engagement with users.                                      | Week 9       | Task 4                     | Functional blog page                |
# | 10      | Optimize site for speed and SEO                                                             | Jane Doe    | Ensure fast loading times through various performance optimizations and integrate SEO best practices for discoverability.                                  | Weeks 10-11  | Tasks 4, 6-9                | Optimized website                    |
# | 11      | Integrate social media links and sharing capabilities                                        | Jane Doe    | Add social media links and enable sharing options on services and blog posts to increase outreach.                                                        | Week 11      | Task 10                     | Social media integration            |
# | 12      | Create a testimonials section                                                                 | Jane Doe    | Design and implement a section dedicated to customer feedback and testimonials to build trust with prospective clients.                                   | Week 12      | Task 10                     | Populated testimonials section       |
# | 13      | Conduct QA testing                                                                           | Alice Johnson, Tom Brown | Perform extensive testing of the website for functionality, usability, and compatibility across various devices and browsers.                              | Weeks 13-14  | Tasks 5-12                  | QA testing report                   |
# | 14      | Launch the website                                                                           | John Doe    | Finalize all details, ensure hosting is in place, and go live with the website following successful QA testing approval.                                   | Week 15      | Task 13                     | Live website                        |
#
# ### Gantt Chart Visualization:
#
# ```plaintext
# | Task                             | Week 1 | Week 2 | Week 3 | Week 4 | Week 5 | Week 6 | Week 7 | Week 8 | Week 9 | Week 10 | Week 11 | Week 12 | Week 13 | Week 14 | Week 15 |
# |----------------------------------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|---------|---------|---------|---------|---------|
# | Gathering requirements            | ██████ |        |        |        |        |        |        |        |        |         |         |         |         |         |         |
# | Site map and wireframe           |        | ██████ |        |        |        |        |        |        |        |         |         |         |         |         |         |
# | UI design                        |        |        | ██████ | ██████ |        |        |        |        |        |         |         |         |         |         |         |
# | Frontend development              |        |        |        |        | ██████ | ██████ |        |        |        |         |         |         |         |         |         |
# | Navigation system                 |        |        |        |        |        | ██████ |        |        |        |         |         |         |         |         |         |
# | About Us page                     |        |        |        |        |        |        | ██████ |        |        |         |         |         |         |         |         |
# | Services page                     |        |        |        |        |        |        | ██████ |        |        |         |         |         |         |         |         |
# | Contact Us page                   |        |        |        |        |        |        |        | ██████ |        |         |         |         |         |         |         |
# | Blog section                      |        |        |        |        |        |        |        | ██████ |        |         |         |         |         |         |         |
# | Speed and SEO optimization        |        |        |        |        |        |        |        |        | ██████ | ████    |         |         |         |         |         |
# | Social media integration          |        |        |        |        |        |        |        |        |        | ██████  |         |         |         |         |         |
# | Testimonials section              |        |        |        |        |        |        |        |        |        |         | █████   |         |         |         |         |
# | QA testing                        |        |        |        |        |        |        |        |        |        |         |         | █████   | █████   |         |         |
# | Website launch                    |        |        |        |        |        |        |        |        |        |         |         |         |         | █████   |         |
# ```
#
# ### Conclusion:
# By adhering to this project breakdown, each aspect of the Website project will be carefully managed, ensuring timely delivery and alignment with the business’ goals. This plan sets a clear framework for the roles of team members, timelines, and deliverables, ultimately contributing to a successful website that meets the specified requirements.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Detailed Estimation Report for Website Project
#
# **Project Overview:**
# Create a responsive and visually appealing website for a small business that effectively communicates its offerings and enhances customer engagement.
#
# #### Task Estimations:
#
# | Task ID | Task Description                                                                            | Time Estimate    | Resources Required                     | Effort Estimate (in hours) | Risks/Uncertainties                                          |
# |---------|---------------------------------------------------------------------------------------------|------------------|---------------------------------------|-----------------------------|---------------------------------------------------------|
# | 1       | Gather and finalize project requirements                                                    | 1 week           | 1 Project Manager, Stakeholders       | 40 hours                    | Stakeholder availability could delay finalization.      |
# | 2       | Create a site map and wireframe for the website                                            | 1 week           | 1 UX/UI Designer                       | 30 hours                    | Misunderstanding design requirements might lead to rework. |
# | 3       | Design responsive website UI                                                                | 2 weeks          | 1 UX/UI Designer                       | 80 hours                    | Potential design revisions based on feedback.             |
# | 4       | Develop website frontend initiative                                                         | 3 weeks          | 1 Frontend Developer, 1 Designer      | 120 hours                   | Technical challenges with coding or design implementation. |
# | 5       | Build user-friendly navigation system                                                       | 1 week           | 1 Frontend Developer                   | 30 hours                    | Navigation complexity may cause integration issues.       |
# | 6       | Create "About Us" page                                                                      | 1 week           | 1 Content Creator                      | 20 hours                    | Delay in content approval from stakeholders.               |
# | 7       | Design "Services" page                                                                      | 1 week           | 1 Content Creator                      | 20 hours                    | Changes in service offerings may require additional edits.  |
# | 8       | Create "Contact Us" page                                                                    | 1 week           | 1 Frontend Developer                   | 30 hours                    | Issues with form functionality may affect go-live.        |
# | 9       | Implement a blog section                                                                     | 1 week           | 1 Content Creator, 1 Frontend Dev.    | 40 hours                    | Blog integration with frontend may require adjustments.    |
# | 10      | Optimize site for speed and SEO                                                             | 2 weeks          | 1 Frontend Developer                   | 60 hours                    | Unforeseen site speed issues may extend optimization time.  |
# | 11      | Integrate social media links and sharing capabilities                                        | 1 week           | 1 Frontend Developer                   | 30 hours                    | API changes from social platforms could cause delays.      |
# | 12      | Create a testimonials section                                                                 | 1 week           | 1 Content Creator, 1 Frontend Dev.    | 30 hours                    | Collecting client testimonials may face delays.            |
# | 13      | Conduct QA testing                                                                           | 2 weeks          | 2 Testers                              | 80 hours                    | Discovering major bugs late could delay launch.           |
# | 14      | Launch the website                                                                           | 1 week           | 1 Project Manager, All Team Members   | 40 hours                    | Last-minute issues may arise affecting launch timing.      |
#
# ### Summary of Risks
# - **Stakeholder Delay**: The constant availability of stakeholders for feedback and approvals could pose risks to timelines.
# - **Technical Challenges**: Development tasks may face unexpected technical hurdles requiring additional time.
# - **Content Approval**: Delays in feedback on content may impact the timeline, especially for crucial pages.
# - **Design Changes**: Changes requested after the design phase can incur rework and additional time.
# - **Last-Minute Testing Issues**: Major bug discovery during testing can delay the launch phase significantly.
#
# By combining historical data with task complexity and resource constraints, this estimation plan should reduce the risk of delays and help maintain the project within budget while delivering the desired outcomes effectively. Each task timeline is designed to allow flexibility for revisions while aiming for a successful launch of the website that aligns with the small business's goals.
#
# This comprehensive breakdown will ensure that all involved parties are aware of expectations, enabling smoother execution throughout the project's lifecycle.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# {
#   "tasks": [
#     {
#       "task_name": "Gather and finalize project requirements",
#       "estimated_time_hours": 40,
#       "required_resources": ["John Doe"]
#     },
#     {
#       "task_name": "Create a site map and wireframe for the website",
#       "estimated_time_hours": 30,
#       "required_resources": ["Bob Smith"]
#     },
#     {
#       "task_name": "Design responsive website UI",
#       "estimated_time_hours": 80,
#       "required_resources": ["Bob Smith"]
#     },
#     {
#       "task_name": "Develop website frontend initiative",
#       "estimated_time_hours": 120,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Build user-friendly navigation system",
#       "estimated_time_hours": 30,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Create 'About Us' page",
#       "estimated_time_hours": 20,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Design 'Services' page",
#       "estimated_time_hours": 20,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Create 'Contact Us' page",
#       "estimated_time_hours": 30,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Implement a blog section",
#       "estimated_time_hours": 40,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Optimize site for speed and SEO",
#       "estimated_time_hours": 60,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Integrate social media links and sharing capabilities",
#       "estimated_time_hours": 30,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Create a testimonials section",
#       "estimated_time_hours": 30,
#       "required_resources": ["Jane Doe"]
#     },
#     {
#       "task_name": "Conduct QA testing",
#       "estimated_time_hours": 80,
#       "required_resources": ["Alice Johnson", "Tom Brown"]
#     },
#     {
#       "task_name": "Launch the website",
#       "estimated_time_hours": 40,
#       "required_resources": ["John Doe"]
#     }
#   ],
#   "milestones": [
#     {
#       "milestone_name": "Project Requirements Finalized",
#       "tasks": ["Gather and finalize project requirements"]
#     },
#     {
#       "milestone_name": "Design Phase Complete",
#       "tasks": [
#         "Create a site map and wireframe for the website",
#         "Design responsive website UI"
#       ]
#     },
#     {
#       "milestone_name": "Frontend Development Complete",
#       "tasks": [
#         "Develop website frontend initiative",
#         "Build user-friendly navigation system",
#         "Create 'About Us' page",
#         "Design 'Services' page",
#         "Create 'Contact Us' page",
#         "Implement a blog section"
#       ]
#     },
#     {
#       "milestone_name": "SEO and Performance Optimization Complete",
#       "tasks": [
#         "Optimize site for speed and SEO",
#         "Integrate social media links and sharing capabilities",
#         "Create a testimonials section"
#       ]
#     },
#     {
#       "milestone_name": "QA Testing Complete",
#       "tasks": ["Conduct QA testing"]
#     },
#     {
#       "milestone_name": "Website Launched",
#       "tasks": ["Launch the website"]
#     }
#   ]
# }
#
# Rationale:
# 1. **Project Management:** John Doe, the Project Manager, will gather project requirements, ensuring clear direction and stakeholder engagement.
# 2. **Design Tasks:** Bob Smith is uniquely equipped to handle both the site map/wireframe (Task 2) and UI design (Task 3), as they are essential for visual coherence.
# 3. **Frontend Development:** Jane Doe, being a Software Engineer, will handle the bulk of development tasks, ensuring a seamless transition from design to functional frontend (Tasks 4-9). This reduces communication overhead and maintains a strong alignment with design specifications.
# 4. **QA Responsibilities:** Alice Johnson and Tom Brown, as QA Engineers, share responsibility for comprehensive testing, ensuring a robust final product prior to launch (Task 13).
# 5. **Sequential Dependencies:** Tasks are allocated while considering dependencies, allowing for smooth transition and minimal bottlenecks in the workflow.
# 6. **Load Management:** This distribution ensures an even workload among team members, preventing burnout, while leveraging their individual strengths for the maximum output efficiency.
#
# In summary, this structured allocation ensures that the project stays on track, hitting all crucial milestones while addressing the necessary skill alignment for each task. This strategy maximizes resource utilization and promotes project success within the stipulated timeline.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0013
#    total_tokens  prompt_tokens  cached_prompt_tokens  completion_tokens  \
# 0          8602           5175                     0               3427
#
#    successful_requests
# 0                    3

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_34af2 th {
#   font-size: 120%;
# }
# #T_34af2  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_34af2" class="dataframe">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_34af2_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_34af2_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_34af2_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34af2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_34af2_row0_col0" class="data row0 col0" >Gather and finalize project requirements</td>
#       <td id="T_34af2_row0_col1" class="data row0 col1" >40.000000</td>
#       <td id="T_34af2_row0_col2" class="data row0 col2" >['John Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_34af2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_34af2_row1_col0" class="data row1 col0" >Create a site map and wireframe for the website</td>
#       <td id="T_34af2_row1_col1" class="data row1 col1" >30.000000</td>
#       <td id="T_34af2_row1_col2" class="data row1 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_34af2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_34af2_row2_col0" class="data row2 col0" >Design responsive website UI</td>
#       <td id="T_34af2_row2_col1" class="data row2 col1" >80.000000</td>
#       <td id="T_34af2_row2_col2" class="data row2 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_34af2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_34af2_row3_col0" class="data row3 col0" >Develop website frontend initiative</td>
#       <td id="T_34af2_row3_col1" class="data row3 col1" >120.000000</td>
#       <td id="T_34af2_row3_col2" class="data row3 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_34af2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_34af2_row4_col0" class="data row4 col0" >Build user-friendly navigation system</td>
#       <td id="T_34af2_row4_col1" class="data row4 col1" >30.000000</td>
#       <td id="T_34af2_row4_col2" class="data row4 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_34af2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_34af2_row5_col0" class="data row5 col0" >Create 'About Us' page</td>
#       <td id="T_34af2_row5_col1" class="data row5 col1" >20.000000</td>
#       <td id="T_34af2_row5_col2" class="data row5 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_34af2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_34af2_row6_col0" class="data row6 col0" >Design 'Services' page</td>
#       <td id="T_34af2_row6_col1" class="data row6 col1" >20.000000</td>
#       <td id="T_34af2_row6_col2" class="data row6 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_34af2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_34af2_row7_col0" class="data row7 col0" >Create 'Contact Us' page</td>
#       <td id="T_34af2_row7_col1" class="data row7 col1" >30.000000</td>
#       <td id="T_34af2_row7_col2" class="data row7 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_34af2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_34af2_row8_col0" class="data row8 col0" >Implement a blog section</td>
#       <td id="T_34af2_row8_col1" class="data row8 col1" >40.000000</td>
#       <td id="T_34af2_row8_col2" class="data row8 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_34af2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_34af2_row9_col0" class="data row9 col0" >Optimize site for speed and SEO</td>
#       <td id="T_34af2_row9_col1" class="data row9 col1" >60.000000</td>
#       <td id="T_34af2_row9_col2" class="data row9 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_34af2_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_34af2_row10_col0" class="data row10 col0" >Integrate social media links and sharing capabilities</td>
#       <td id="T_34af2_row10_col1" class="data row10 col1" >30.000000</td>
#       <td id="T_34af2_row10_col2" class="data row10 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_34af2_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_34af2_row11_col0" class="data row11 col0" >Create a testimonials section</td>
#       <td id="T_34af2_row11_col1" class="data row11 col1" >30.000000</td>
#       <td id="T_34af2_row11_col2" class="data row11 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_34af2_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_34af2_row12_col0" class="data row12 col0" >Conduct QA testing</td>
#       <td id="T_34af2_row12_col1" class="data row12 col1" >80.000000</td>
#       <td id="T_34af2_row12_col2" class="data row12 col2" >['Alice Johnson', 'Tom Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_34af2_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_34af2_row13_col0" class="data row13 col0" >Launch the website</td>
#       <td id="T_34af2_row13_col1" class="data row13 col1" >40.000000</td>
#       <td id="T_34af2_row13_col2" class="data row13 col2" >['John Doe']</td>
#     </tr>
#   </tbody>
# </table>

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_4a1cf th {
#   font-size: 120%;
# }
# #T_4a1cf  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_4a1cf" class="dataframe">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a1cf_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_4a1cf_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a1cf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4a1cf_row0_col0" class="data row0 col0" >Project Requirements Finalized</td>
#       <td id="T_4a1cf_row0_col1" class="data row0 col1" >['Gather and finalize project requirements']</td>
#     </tr>
#     <tr>
#       <th id="T_4a1cf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4a1cf_row1_col0" class="data row1 col0" >Design Phase Complete</td>
#       <td id="T_4a1cf_row1_col1" class="data row1 col1" >['Create a site map and wireframe for the website', 'Design responsive website UI']</td>
#     </tr>
#     <tr>
#       <th id="T_4a1cf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4a1cf_row2_col0" class="data row2 col0" >Frontend Development Complete</td>
#       <td id="T_4a1cf_row2_col1" class="data row2 col1" >['Develop website frontend initiative', 'Build user-friendly navigation system', "Create 'About Us' page", "Design 'Services' page", "Create 'Contact Us' page", 'Implement a blog section']</td>
#     </tr>
#     <tr>
#       <th id="T_4a1cf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4a1cf_row3_col0" class="data row3 col0" >SEO and Performance Optimization Complete</td>
#       <td id="T_4a1cf_row3_col1" class="data row3 col1" >['Optimize site for speed and SEO', 'Integrate social media links and sharing capabilities', 'Create a testimonials section']</td>
#     </tr>
#     <tr>
#       <th id="T_4a1cf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4a1cf_row4_col0" class="data row4 col0" >QA Testing Complete</td>
#       <td id="T_4a1cf_row4_col1" class="data row4 col1" >['Conduct QA testing']</td>
#     </tr>
#     <tr>
#       <th id="T_4a1cf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_4a1cf_row5_col0" class="data row5 col0" >Website Launched</td>
#       <td id="T_4a1cf_row5_col1" class="data row5 col1" >['Launch the website']</td>
#     </tr>
#   </tbody>
# </table>
